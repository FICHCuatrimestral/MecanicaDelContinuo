# %%
import sys
import numpy as np
import scipy
import matplotlib.pyplot as plt
import subprocess

# 1. Verificar librerías
print(f"Versión de Python: {sys.version}")
print(f"Numpy OK (v{np.__version__})")
print(f"Scipy OK (v{scipy.__version__})")
print(f"Matplotlib OK (v{plt.style.available[0]})")

# 2. Verificar ffmpeg (vital para el punto d)
try:
    ffmpeg_version = subprocess.check_output(["ffmpeg", "-version"]).decode().split('\n')[0]
    print(f"FFMPEG OK: {ffmpeg_version}")
except:
    print("❌ ERROR: ffmpeg no encontrado. Revisa el postCreateCommand.")
# Out:
# Versión de Python: 3.12.13 (main, Mar  3 2026, 20:23:47) [GCC 14.2.0]
# Numpy OK (v1.26.4)
# Scipy OK (v1.13.0)
# Matplotlib OK (vSolarize_Light2)
# FFMPEG OK: ffmpeg version 7.1.3-0+deb13u1 Copyright (c) 2000-2025 the FFmpeg developers
