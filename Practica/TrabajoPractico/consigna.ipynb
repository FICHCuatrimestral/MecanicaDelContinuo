# %% [markdown]
# # Trabajo Práctico 1 — Mecánica del Continuo
# ### Bertona · Deharbe · García · Keiner &nbsp;|&nbsp; Caso 4
#
# Análisis dinámico de un reticulado plano de **10 nodos** y **15 barras** sometido a una carga uniforme $P(t) = 10$ N en la dirección $x$ del nodo 10. El sistema de $2 \times 10 = 20$ grados de libertad se integra en $[0,\, 50]$ s con `scipy.integrate.solve_ivp`.
#
# | Parte | Descripción |
# |:-----:|-------------|
# | **A** | Dos modelos: deformaciones finitas **(a.i)** y pequeños desplazamientos **(a.ii)** |
# | **B** | Tensiones, desplazamientos y tiempo de colapso $t_F$ para ambos modelos |
# | **C** | Amortiguador de arrastre fluido en el nodo $c = 10$ |
# | **D** | Animaciones de la estructura deformada en el tiempo |

# %%
import sys
import numpy as np
import pandas as pd
import scipy
import matplotlib.pyplot as plt
import subprocess
from scipy.integrate import solve_ivp
import matplotlib.pyplot as plt
from IPython.display import display

# %% [markdown]
# ### Datos del Problema (Caso 4)
#
# **Tabla de Conectividad del Reticulado:**
#
# | Barra | Nodo $i$ ($N_i$) | Nodo $j$ ($N_j$) |
# |:---:|:---:|:---:|
# | 1 | 1 | 3 |
# | 2 | 3 | 4 |
# | 3 | 4 | 1 |
# | 4 | 4 | 2 |
# | 5 | 2 | 5 |
# | 6 | 5 | 4 |
# | 7 | 3 | 8 |
# | 8 | 8 | 9 |
# | 9 | 9 | 5 |
# | 10 | 8 | 4 |
# | 11 | 4 | 9 |
# | 12 | 8 | 10 |
# | 13 | 10 | 9 |
# | 14 | 9 | 7 |
# | 15 | 8 | 6 |
#
# **Parámetros Físicos y Geométricos:**
#
# * **Densidad de la barra:** $\rho = 1$
# * **Módulo de elasticidad longitudinal:** $E = 50$
# * **Área de la sección transversal:** $A = 2$
# * **Carga uniforme:** $P(t) = 10$
#
# **Parámetros del Sistema Amortiguador (Parte C):**
#
# * **Densidad del fluido:** $\rho_{fl} = 3.0$
# * **Radio de la esfera amortiguadora:** $r_{esf} = 1.5$
# * **Cota de la superficie libre del fluido:** $h_{SL} = 25$
#
# **Elementos de Análisis (Parte B y C):**
#
# * **Barra de análisis:** $a = 8$
# * **Nodo de análisis de coordenadas:** $b = 10$
# * **Nodo con amortiguador:** $c = 10$
#
# ![NuestroCaso](Imagenes/caso.png)

# %% [markdown]
# ### Parte A: Cálculo de la Respuesta Dinámica
#
# **Desarrolle un programa computacional** que calcule la respuesta dinámica del sistema ante una carga $P(t)$ definida por una función uniforme en el tiempo, en un periodo de tiempo de 0 a 50 segundos máximo ($t_{F\_Max}$).
#
#
# ![grafica](Imagenes/grafica.png)
#
#
# Considere dos situaciones:
#
# **i. Fuerzas en la configuración deformada:** Que la dirección de las fuerzas sigue la dirección de las barras durante todo el proceso de deformación, es decir, el de las barras en la configuración deformada.
# > *Nota:* Esta condición está relacionada con lo que se conoce como **hipótesis de deformaciones finitas**, que se desarrolla en la cátedra en temas posteriores.
#
# **ii. Fuerzas en la configuración de referencia:**
# Que las fuerzas mantienen la dirección del reticulado no deformado, es decir, la de la configuración de referencia.
# > *Nota:* Acá se adopta una hipótesis simplificativa para la solución del problema que supone pequeños desplazamientos de los nodos y pequeños giros de las barras. Este tipo de hipótesis facilita la resolución del problema considerando que algunos términos son despreciables frente a otros. Razonamientos similares se emplean en la **hipótesis de deformaciones infinitesimales**, que también se desarrolla posteriormente en la cátedra.

# %% [markdown]
# #### Paso 1 — Inicialización del sistema
#
# Se cargan los datos del Caso 4: parámetros físicos, conectividad, coordenadas nodales y condiciones de borde. La masa concentrada en cada nodo se obtiene distribuyendo la mitad de la masa de cada barra convergente en él (masa lumpeada).

# %%
# ---------------------------------------------------------
# 1. PARÁMETROS FÍSICOS Y GEOMÉTRICOS
# ---------------------------------------------------------
elasticidad = 50.0          # Módulo de elasticidad longitudinal (E)
area = 2.0                  # Área de sección transversal (A)
densidad_barra = 1.0             # Densidad de la barra
carga_externa = 10.0              # Magnitud de la carga uniforme

# ---------------------------------------------------------
# 2. CONECTIVIDAD Y COORDENADAS
# ---------------------------------------------------------
# Array con formato [Nodo_i, Nodo_j] (Restamos 1 para índices de Python)
conectividad = np.array([
    [1, 3],  [3, 4],  [4, 1],  [4, 2],  [2, 5], 
    [5, 4],  [3, 8],  [8, 9],  [9, 5],  [8, 4], 
    [4, 9],  [8, 10], [10, 9], [9, 7],  [8, 6]  
]) - 1

coordenadas = np.array([
    [0.0, 0.0],    # Nodo 1 (Índice 0)
    [10.0, 0.0],   # Nodo 2 (Índice 1)
    [5.0, 10.0],   # Nodo 3 (Índice 2)
    [10.0, 10.0],  # Nodo 4 (Índice 3)
    [15.0, 10.0],  # Nodo 5 (Índice 4)
    [0.0, 15.0],   # Nodo 6 (Índice 5)
    [20.0, 15.0],  # Nodo 7 (Índice 6)
    [5.0, 20.0],   # Nodo 8 (Índice 7)
    [15.0, 20.0],  # Nodo 9 (Índice 8)
    [10.0, 25.0]   # Nodo 10 (Índice 9)
])

num_nodos = len(coordenadas)
num_grados_libertad = num_nodos * 2  # 2 Grados de Libertad (X e Y) por cada nodo

# ---------------------------------------------------------
# 3. CONDICIONES DE BORDE Y CARGAS
# ---------------------------------------------------------
# GDL restringidos: Nodo 1 (0, 1), Nodo 2 en Y (3), Nodo 6 (10, 11)
gdl_restringidos = [0, 1, 3, 10, 11]

# Vector de cargas externas (Carga P en GDL 18)
F_externa = np.zeros(num_grados_libertad)
F_externa[18] = carga_externa

# ---------------------------------------------------------
# 4. CÁLCULO DE LONGITUDES INICIALES Y MASAS
# ---------------------------------------------------------
num_barras = len(conectividad)
longitudes_iniciales = np.zeros(num_barras)
masa_por_barra = np.zeros(num_barras)
masas_nodales = np.zeros(num_grados_libertad)

for b in range(num_barras):
    nodo_i = conectividad[b, 0]
    nodo_j = conectividad[b, 1]
    
    xi, yi = coordenadas[nodo_i]
    xj, yj = coordenadas[nodo_j]
    
    dx = xj - xi
    dy = yj - yi
    
    # Longitud inicial y masa de la barra
    longitud = np.sqrt(dx**2 + dy**2)
    longitudes_iniciales[b] = longitud
    masa_barra = area * longitud * densidad_barra
    masa_por_barra[b] = masa_barra
    
    # Ensamblaje en la matriz/vector de masa global
    masas_nodales[2*nodo_i]     += masa_barra / 2.0
    masas_nodales[2*nodo_i + 1] += masa_barra / 2.0
    masas_nodales[2*nodo_j]     += masa_barra / 2.0
    masas_nodales[2*nodo_j + 1] += masa_barra / 2.0

# ---------------------------------------------------------
# 5. IMPRESIÓN DE RESULTADOS EN TABLAS
# ---------------------------------------------------------
# Tabla de Barras
df_barras = pd.DataFrame({
    'Barra': range(1, num_barras + 1),
    'Nodo i': conectividad[:, 0] + 1,
    'Nodo j': conectividad[:, 1] + 1,
    'L₀ [m]': longitudes_iniciales,
    'Masa Total': masa_por_barra
})

# Tabla de Masas Nodales
# Tomamos solo los valores pares de masas_nodales, ya que la masa en X e Y es igual para cada nodo
df_masas_nodales = pd.DataFrame({
    'Nodo': range(1, num_nodos + 1),
    'Masa Concentrada (X e Y)': masas_nodales[0::2] 
})

display(
    df_barras.style
    .set_caption("Propiedades de las barras")
    .format({"L₀ [m]": "{:.4f}", "Masa Total": "{:.4f}"})
    .hide(axis="index")
)
display(
    df_masas_nodales.style
    .set_caption("Masas nodales concentradas (por GDL)")
    .format({"Masa Concentrada (X e Y)": "{:.4f}"})
    .hide(axis="index")
)
# --- 6. ESTADO INICIAL PARA EL SOLUCIONADOR ---
# Posiciones iniciales aplanadas (20 elementos)
posiciones_iniciales = coordenadas.flatten()

# Velocidades iniciales (20 ceros)
velocidades_iniciales = np.zeros(num_grados_libertad)

# Unimos todo en un solo vector estado_inicial de 40 elementos
estado_inicial = np.concatenate((posiciones_iniciales, velocidades_iniciales))
print(f"✓ Estado inicial ensamblado: {len(estado_inicial)} variables ({num_nodos} nodos × 2 coordenadas + {num_nodos} velocidades)")
# Out:
# <style type="text/css">
# </style>
# <table id="T_343bf">
#   <caption>Propiedades de las barras</caption>
#   <thead>
#     <tr>
#       <th id="T_343bf_level0_col0" class="col_heading level0 col0" >Barra</th>
#       <th id="T_343bf_level0_col1" class="col_heading level0 col1" >Nodo i</th>
#       <th id="T_343bf_level0_col2" class="col_heading level0 col2" >Nodo j</th>
#       <th id="T_343bf_level0_col3" class="col_heading level0 col3" >L₀ [m]</th>
#       <th id="T_343bf_level0_col4" class="col_heading level0 col4" >Masa Total</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_343bf_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_343bf_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_343bf_row0_col2" class="data row0 col2" >3</td>
#       <td id="T_343bf_row0_col3" class="data row0 col3" >11.1803</td>
#       <td id="T_343bf_row0_col4" class="data row0 col4" >22.3607</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# #### Paso 2 — Funciones de derivadas del estado
#
# Las dos hipótesis de la Parte A se implementan como funciones `f(t, Y)` para el integrador. El estado es $\mathbf{Y} = [\mathbf{q},\, \dot{\mathbf{q}}] \in \mathbb{R}^{40}$ y la salida es $[\dot{\mathbf{q}},\, \ddot{\mathbf{q}}]$.

# %%
def calcular_derivadas(t, Y):
    posiciones = Y[:num_grados_libertad]
    velocidades = Y[num_grados_libertad:]
    
    F_interna = np.zeros(num_grados_libertad)
    
    for b in range(num_barras):
        nodo_i = conectividad[b, 0]
        nodo_j = conectividad[b, 1]
        
        xi_actual, yi_actual = posiciones[2*nodo_i], posiciones[2*nodo_i + 1]
        xj_actual, yj_actual = posiciones[2*nodo_j], posiciones[2*nodo_j + 1]
        
        dx_actual = xj_actual - xi_actual
        dy_actual = yj_actual - yi_actual
        
        # Agregamos un número pequeñísimo (1e-9) para evitar división por cero
        longitud_actual = np.sqrt(dx_actual**2 + dy_actual**2) + 1e-9
        
        # Rigidez axial según la ley de elasticidad [cite: 69, 74]
        fuerza_resorte = ((elasticidad * area) / longitudes_iniciales[b]) * (longitud_actual - longitudes_iniciales[b])
        
        Fx = fuerza_resorte * (dx_actual / longitud_actual)
        Fy = fuerza_resorte * (dy_actual / longitud_actual)
        
        F_interna[2*nodo_i]     += Fx
        F_interna[2*nodo_i + 1] += Fy
        F_interna[2*nodo_j]     -= Fx
        F_interna[2*nodo_j + 1] -= Fy
        
    F_neta = F_externa + F_interna
    F_neta[gdl_restringidos] = 0.0
    
    # Protección: Si la masa es 0 (no debería), usamos un valor muy grande para que no acelere
    # Esto evita el error de NaNs [cite: 231]
    aceleraciones = np.where(masas_nodales > 0, F_neta / masas_nodales, 0.0)
    
    return np.concatenate((velocidades, aceleraciones))

# %%
# --- 1. FUNCIÓN MOTOR MODELO A.II (PEQUEÑOS DESPLAZAMIENTOS) ---
def calcular_derivadas_pequenos(t, Y):
    posiciones = Y[:num_grados_libertad]
    velocidades = Y[num_grados_libertad:]
    
    # En este modelo, el desplazamiento es la clave
    desplazamientos = posiciones - coordenadas.flatten()
    F_interna = np.zeros(num_grados_libertad)
    
    for b in range(num_barras):
        nodo_i = conectividad[b, 0]
        nodo_j = conectividad[b, 1]
        
        # USAMOS SIEMPRE LA GEOMETRÍA ORIGINAL (Referencia)
        xi, yi = coordenadas[nodo_i]
        xj, yj = coordenadas[nodo_j]
        dx = xj - xi
        dy = yj - yi
        L_orig = longitudes_iniciales[b]
        
        # Cosenos y senos fijos
        cos = dx / L_orig
        sen = dy / L_orig
        
        # Proyectamos los desplazamientos sobre el eje de la barra
        du = desplazamientos[2*nodo_j] - desplazamientos[2*nodo_i]
        dv = desplazamientos[2*nodo_j+1] - desplazamientos[2*nodo_i+1]
        
        # El alargamiento es una aproximación lineal
        alargamiento = du * cos + dv * sen
        fuerza_resorte = ((elasticidad * area) / L_orig) * alargamiento
        
        Fx = fuerza_resorte * cos
        Fy = fuerza_resorte * sen
        
        F_interna[2*nodo_i]     += Fx
        F_interna[2*nodo_i + 1] += Fy
        F_interna[2*nodo_j]     -= Fx
        F_interna[2*nodo_j + 1] -= Fy
        
    F_neta = F_externa + F_interna
    F_neta[gdl_restringidos] = 0.0
    
    # Segunda Ley de Newton
    aceleraciones = np.where(masas_nodales > 0, F_neta / masas_nodales, 0.0)
    
    return np.concatenate((velocidades, aceleraciones))

# %% [markdown]
# #### Paso 3 — Integración numérica
#
# El modelo **a.i** usa el método **BDF** (recomendado para sistemas potencialmente rígidos); el **a.ii** usa **RK45** (suficiente por su linealidad). Ambos generan 1 000 puntos de salida en $[0,\, 50]$ s.

# %%
# --- 7. SIMULACIÓN DINÁMICA CON SCIPY ---
print("Iniciando la simulación dinámica (Modelo a.i). Esto puede tardar unos segundos...")

# Rango de tiempo: de 0 a 50 segundos, como indica el PDF
t_span = (0.0, 50.0)

# Para que los gráficos luego queden suaves, le pedimos a SciPy que guarde 
# el resultado en 1000 instantes de tiempo intermedios equiespaciados
t_eval = np.linspace(t_span[0], t_span[1], 1000)

# Llamamos al solucionador. 
# method='BDF' es el equivalente en Python al ODE23S de MatLab
solucion = solve_ivp(
    fun=calcular_derivadas, 
    t_span=t_span, 
    y0=estado_inicial, 
    t_eval=t_eval, 
    method='BDF' 
)

if solucion.success:
    print("¡Simulación terminada con éxito! 🚀")
    tiempo_simulado = solucion.t
    resultados_Y = solucion.y  # Matriz gigante de 40 filas x 1000 columnas
else:
    print("Uy, hubo un problema con la simulación:", solucion.message)
# Out:
# Iniciando la simulación dinámica (Modelo a.i). Esto puede tardar unos segundos...
# ¡Simulación terminada con éxito! 🚀

# %%
# ── Simulación Modelo a.ii: Pequeños Desplazamientos ─────────────────────────
print("Simulando Modelo a.ii (Configuración de Referencia)...")

solucion_aii = solve_ivp(
    fun=calcular_derivadas_pequenos, 
    t_span=(0, 50), 
    y0=estado_inicial, 
    t_eval=np.linspace(0, 50, 1000), 
    method='RK45' # RK45 suele ser más rápido para modelos lineales
)

if solucion_aii.success:
    print(f"¡Simulación a.ii completada! ({len(solucion_aii.t)} pasos)")
else:
    print("Error en a.ii:", solucion_aii.message)
# Out:
# Simulando Modelo a.ii (Configuración de Referencia)...
# ¡Simulación a.ii completada! (1000 pasos)

# %%
# ── Verificación rápida: Posición X del Nodo 10 (ambos modelos) ───────────
fig, axes = plt.subplots(1, 2, figsize=(14, 5))
fig.suptitle('Verificación: Posición X del Nodo 10 (GDL 18)', fontsize=13)

axes[0].plot(solucion.t, solucion.y[18, :], color='steelblue', lw=2)
axes[0].set_title('Modelo a.i  – Deformaciones Finitas')
axes[0].set_xlabel('Tiempo [s]')
axes[0].set_ylabel('Posición X [m]')
axes[0].grid(True, alpha=0.4)

axes[1].plot(solucion_aii.t, solucion_aii.y[18, :], color='forestgreen', lw=2)
axes[1].set_title('Modelo a.ii – Pequeños Desplazamientos')
axes[1].set_xlabel('Tiempo [s]')
axes[1].set_ylabel('Posición X [m]')
axes[1].grid(True, alpha=0.4)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Parte B: Análisis y Comparación de Resultados
#
# En cada una de estas dos situaciones ($a.i$ y $a.ii$), determine lo siguiente:
#
# **i. Condición de Estado Límite (Intersección de barras)**
# Las estructuras se diseñan o dimensionan para satisfacer condiciones de estado límite, que pueden corresponder a deformaciones (por ejemplo, un desplazamiento vertical, o flecha, máximo, de un elemento horizontal como una viga), resistencia (tensiones admisibles o tensiones últimas, como la tensión de fluencia en metales), estabilidad, entre otras.
# * En este ejercicio se adopta como condición límite el **cambio de signo del área de los triángulos cerrados** formados por las barras. Esta situación representa la condición en que las barras se cruzan, lo cual no es físicamente admisible si el movimiento ocurre en el plano.
# * Entonces, se debe determinar para las dos situaciones ($a.i$ y $a.ii$), el primer instante $t_F$ en el que se produce dicho cambio de signo en cualquiera de los triángulos que conforman la geometría de la estructura.
# > *Nota:* Si se supera $t_{F\_Max}$, adoptar que $t_F = t_{F\_Max}$.
#
# **ii. Gráficas de Evolución Temporal**
# Obtenga una gráfica de la evolución, hasta el tiempo $t_{Fa.i}$ o $t_{Fa.ii}$ según corresponda, de:
# * La **tensión normal** (componente normal a la sección transversal) de la barra $a$.
# * La **tensión tangencial** (componente contenida en el plano de la sección transversal) de la barra $a$.
# * La **coordenada actual** del nodo $b$.
#
# **Pregunta de análisis:** ¿Qué ocurre con la tensión tangencial y por qué?
#
# **iii. Desplazamientos y Conclusiones Finales**
# * Determine, en el intervalo $0$ a $\min(t_{Fa.i}, t_{Fa.ii})$, la **norma del vector desplazamiento máxima** entre todos los nodos y el instante en que se alcanza dicho valor.
# * **Compare** la evolución de las tensiones y de la coordenada actual obtenidas para ambas situaciones ($a.i$ y $a.ii$).
# * **Extraiga conclusiones** de las diferencias observadas: indique cuál sería el modelo más adecuado para el problema considerado y en qué intervalo temporal se podría aplicar uno u otro.

# %%
# ─────────────────────────────────────────────
# PARÁMETROS DEL CASO
# ─────────────────────────────────────────────
BARRA_A   = 7   # índice Python de la barra a=8
NODO_B    = 9   # índice Python del nodo b=10
t_F_Max   = 50.0

# %% [markdown]
# ### B.i — Tiempo de Colapso $t_F$: Detección por Cambio de Signo del Área
#
# El criterio de colapso es el **cambio de signo del área con signo** de algún triángulo cerrado de la malla. Cuando el área invierte su signo, las barras que lo forman se han cruzado — situación físicamente inadmisible en movimiento plano.
#
# El área con signo del triángulo de vértices $P_1, P_2, P_3$ se calcula como:
#
# $$A_s = \frac{1}{2}\left[(x_2 - x_1)(y_3 - y_1) - (x_3 - x_1)(y_2 - y_1)\right]$$
#
# Se identifican primero todos los triángulos cerrados de la malla; luego se registra el primer instante $t$ en que $\text{sgn}(A_s(t)) \neq \text{sgn}(A_s(0))$.

# %%
# ─────────────────────────────────────────────────────────────────────────────
# IDENTIFICACIÓN DE TRIÁNGULOS CERRADOS EN LA MALLA
# Se buscan todos los grupos de 3 barras que formen un ciclo cerrado.
# Estrategia: para cada par de barras que comparten un nodo, buscar una
# tercera barra que cierre el triángulo.
# ─────────────────────────────────────────────────────────────────────────────

def encontrar_triangulos(conectividad):
    """Devuelve una lista de tuplas (n1, n2, n3) con los nodos de cada triangulo."""
    #Construimos conjunto de aristas para busqueda rapida
    aristas = set()
    for (i,j) in conectividad:
        aristas.add((min(i,j), max(i,j)))
    
    nodos_por_barra = [(min(i,j),max(i,j)) for (i,j) in conectividad]
    triangulos = []
    aristas_lista = list(aristas)

    for idx_a, (n1,n2) in enumerate(aristas_lista):
        for idx_b in range (idx_a+1,len(aristas_lista)):
            (na,nb) = aristas_lista[idx_b]
            #Buscamos el nodo compartido entre las aristas
            nodos_a = {n1,n2}
            nodos_b = {na,nb}
            comun = nodos_a & nodos_b
            if len(comun) == 1:
                nodo_comun = comun.pop()
                extremo_a = (nodos_a - {nodo_comun}).pop()
                extremo_b = (nodos_b - {nodo_comun}).pop()
                # Verificar si existe la arista que cierra el triangulo
                cierre = (min(extremo_a,extremo_b),max(extremo_a,extremo_b))
                if cierre in aristas:
                    tri = tuple(sorted([nodo_comun, extremo_a, extremo_b]))
                    if tri not in triangulos:
                        triangulos.append(tri)
    return triangulos

triangulos = encontrar_triangulos(conectividad)
df_tri = pd.DataFrame(
    [(k+1, n1+1, n2+1, n3+1) for k,(n1,n2,n3) in enumerate(triangulos)],
    columns=["#", "Nodo 1", "Nodo 2", "Nodo 3"]
)
display(
    df_tri.style
    .set_caption(f"{len(triangulos)} triángulos cerrados identificados")
    .hide(axis="index")
)
# Out:
# <style type="text/css">
# </style>
# <table id="T_9ecd6">
#   <caption>6 triángulos cerrados identificados</caption>
#   <thead>
#     <tr>
#       <th id="T_9ecd6_level0_col0" class="col_heading level0 col0" >#</th>
#       <th id="T_9ecd6_level0_col1" class="col_heading level0 col1" >Nodo 1</th>
#       <th id="T_9ecd6_level0_col2" class="col_heading level0 col2" >Nodo 2</th>
#       <th id="T_9ecd6_level0_col3" class="col_heading level0 col3" >Nodo 3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_9ecd6_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_9ecd6_row0_col1" class="data row0 col1" >4</td>
#       <td id="T_9ecd6_row0_col2" class="data row0 col2" >5</td>
#       <td id="T_9ecd6_row0_col3" class="data row0 col3" >9</td>
#     </tr>
#     <tr>
#       <td id="T_9ecd6_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_9ecd6_row1_col1" class="data row1 col1" >4</td>
#       <td id="T_9ecd6_row1_col2" class="data row1 col2" >8</td>
# ...

# %%
def area_signo(posiciones, n1, n2, n3):
    """Area con signo del triangulo (n1,n2,n3) para un vector de posiciones aplanado"""
    x1, y1 = posiciones[2*n1], posiciones[2*n1+1]
    x2, y2 = posiciones[2*n2], posiciones[2*n2+1]
    x3, y3 = posiciones[2*n3], posiciones[2*n3+1]

    return 0.5*((x2-x1)*(y3-y1) - (x3-x1)*(y2-y1))

# ─────────────────────────────────────────────────────────────────────────────
# FUNCIÓN GENERAL: dado un objeto solución de solve_ivp, detecta t_F
# ─────────────────────────────────────────────────────────────────────────────
def detectar_tF(solucion, triangulos, t_F_max = 50.0):
    """
    Recorre los instantes de tiempo de la solución y detecta el primer t
    en que algún triángulo cambia de signo de área.
    Devuelve (t_F, índice_tiempo, triángulo_crítico).
    """
    tiempos = solucion.t
    posiciones_t = solucion.y[:num_grados_libertad,:] #filas = gdl, cols = tiempo

    #Calculamos los signos de las areas en t=0
    pos_0 = posiciones_t[:,0]
    signos_0 = np.array([np.sign(area_signo(pos_0,*tri))for tri in triangulos])

    for k,t in enumerate(tiempos):
        pos_k = posiciones_t[:,k]
        signos_k = np.array([np.sign(area_signo(pos_k,*tri)) for tri in triangulos])
        cambio = signos_k != signos_0
        #Ignoramos triangulos de area cero inicial
        valido = signos_0 != 0
        if np.any(cambio&valido):
            idx_tri = np.where(cambio & valido)[0][0]
            return t,k,triangulos[idx_tri]
        
    #Si no hay cambio, se adopta t_F_Max
    return t_F_max, len(tiempos)-1, None

# ── Detección para modelo a.i ──
tiempo_colapso_ai, paso_colapso_ai, triangulo_critico_ai = detectar_tF(solucion, triangulos)
# ── Detección para modelo a.ii ──
tiempo_colapso_aii, paso_colapso_aii, triangulo_critico_aii = detectar_tF(solucion_aii, triangulos)

display(
    pd.DataFrame({
        "Modelo": ["a.i — Deformaciones Finitas", "a.ii — Pequeños Desplazamientos"],
        "tF [s]": [tiempo_colapso_ai, tiempo_colapso_aii],
        "Triángulo crítico": [
            str(tuple(n+1 for n in triangulo_critico_ai)) if triangulo_critico_ai else "—",
            str(tuple(n+1 for n in triangulo_critico_aii)) if triangulo_critico_aii else "—"
        ],
        "Estado": [
            "Cruce detectado" if triangulo_critico_ai else "No hay cruce (tF = tF_Max)",
            "Cruce detectado" if triangulo_critico_aii else "No hay cruce (tF = tF_Max)"
        ]
    }).style
    .set_caption("Tiempos de colapso — B.i")
    .format({"tF [s]": "{:.4f}"})
    .hide(axis="index")
)
# Out:
# <style type="text/css">
# </style>
# <table id="T_df8e4">
#   <caption>Tiempos de colapso — B.i</caption>
#   <thead>
#     <tr>
#       <th id="T_df8e4_level0_col0" class="col_heading level0 col0" >Modelo</th>
#       <th id="T_df8e4_level0_col1" class="col_heading level0 col1" >tF [s]</th>
#       <th id="T_df8e4_level0_col2" class="col_heading level0 col2" >Triángulo crítico</th>
#       <th id="T_df8e4_level0_col3" class="col_heading level0 col3" >Estado</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_df8e4_row0_col0" class="data row0 col0" >a.i — Deformaciones Finitas</td>
#       <td id="T_df8e4_row0_col1" class="data row0 col1" >50.0000</td>
#       <td id="T_df8e4_row0_col2" class="data row0 col2" >—</td>
#       <td id="T_df8e4_row0_col3" class="data row0 col3" >No hay cruce (tF = tF_Max)</td>
#     </tr>
#     <tr>
#       <td id="T_df8e4_row1_col0" class="data row1 col0" >a.ii — Pequeños Desplazamientos</td>
# ...

# %% [markdown]
# ### B.ii — Evolución Temporal hasta $t_F$
#
# Para cada modelo se grafican desde $t = 0$ hasta su propio tiempo de colapso:
#
# - **Tensión normal** $\sigma_n = F_{\text{axial}} / A$ — barra $a = 8$
# - **Tensión tangencial** $\tau$ — barra $a = 8$ (ver análisis a continuación)
# - **Coordenadas actuales** $(x,\, y)$ del nodo $b = 10$

# %%
# ─────────────────────────────────────────────────────────────────────────────
# FUNCIONES DE POST-PROCESO: tensiones en una barra para todos los instantes
# ─────────────────────────────────────────────────────────────────────────────

def calcular_tension_barra_ai(solucion, barra_idx, paso_final):
    """
    Modelo a.i (deformaciones finitas): geometría deformada.
    Tensión normal  = F_axial / A
    Tensión tangencial = 0 en barras de reticulado (solo esfuerzo axial).
    """

    nodo_i = conectividad[barra_idx,0]
    nodo_j = conectividad[barra_idx,1]
    L_orig = longitudes_iniciales[barra_idx]

    posiciones_t = solucion.y[:num_grados_libertad,:paso_final+1]

    sigma_n = np.zeros(paso_final+1)
    tau = np.zeros(paso_final+1)   #Siempre 0 en reticulado ideal

    for k in range(paso_final+1):
        pos = posiciones_t[:,k]
        xi, yi = pos[2*nodo_i],pos[2*nodo_i+1]
        xj, yj = pos[2*nodo_j],pos[2*nodo_j+1]
        dx = xj-xi
        dy = yj-yi
        L_actual = np.sqrt(dx**2 + dy**2)
        #Fuerza axial (positiva = traccion)
        F_axial = (elasticidad*area/L_orig)*(L_actual-L_orig)
        sigma_n[k] = F_axial/area

    return sigma_n,tau

def calcular_tension_barra_aii(solucion, barra_idx, paso_final):
    """
    Modelo a.ii (pequeños desplazamientos): proyección sobre eje original.
    """
    nodo_i = conectividad[barra_idx,0]
    nodo_j = conectividad[barra_idx,1]
    L_orig = longitudes_iniciales[barra_idx]

    xi0, yi0 = coordenadas[nodo_i]
    xj0, yj0 = coordenadas[nodo_j]
    dx0 = xj0 - xi0
    dy0 = yj0 - yi0
    cos0 = dx0/L_orig
    sen0 = dy0/L_orig

    posiciones_t = solucion.y[:num_grados_libertad, :paso_final+1]
    pos_ref = coordenadas.flatten()

    sigma_n = np.zeros(paso_final+1)
    tau = np.zeros(paso_final+1)

    for k in range(paso_final+1):
        pos = posiciones_t[:,k]
        despl = pos-pos_ref
        du = despl[2*nodo_j]-despl[2*nodo_i]
        dv = despl[2*nodo_j+1]-despl[2*nodo_i+1]
        alargamiento = du*cos0+dv*sen0
        F_axial = (elasticidad*area/L_orig)*alargamiento
        sigma_n[k] = F_axial/area

    return sigma_n,tau

# ── Calculamos tensiones para ambos modelos ──
t_ai  = solucion.t[:paso_colapso_ai+1]
t_aii = solucion_aii.t[:paso_colapso_aii+1]

sigma_ai,  tau_ai  = calcular_tension_barra_ai (solucion,     BARRA_A, paso_colapso_ai)
sigma_aii, tau_aii = calcular_tension_barra_aii(solucion_aii, BARRA_A, paso_colapso_aii)

# ── Coordenadas del Nodo b ──
coord_x_ai  = solucion.y[2*NODO_B,   :paso_colapso_ai+1]
coord_y_ai  = solucion.y[2*NODO_B+1, :paso_colapso_ai+1]
coord_x_aii = solucion_aii.y[2*NODO_B,   :paso_colapso_aii+1]
coord_y_aii = solucion_aii.y[2*NODO_B+1, :paso_colapso_aii+1]

# %%
# ─────────────────────────────────────────────────────────────────────────────
# GRÁFICAS — MODELO a.i
# ─────────────────────────────────────────────────────────────────────────────

fig, axes = plt.subplots(3, 1, figsize=(12, 12))
fig.suptitle(f'Modelo a.i — Hasta $t_F$ = {tiempo_colapso_ai:.3f} s', fontsize=14, fontweight='bold')

# Tensión normal
axes[0].plot(t_ai, sigma_ai, color='royalblue', lw=2)
axes[0].set_title(f'Tensión Normal $\\sigma_n$ — Barra {BARRA_A+1}')
axes[0].set_xlabel('Tiempo [s]')
axes[0].set_ylabel('$\\sigma_n$ [unid. de fuerza / área]')
axes[0].axhline(0, color='gray', lw=0.8, ls='--')
axes[0].grid(True, alpha=0.4)

# Tensión tangencial
axes[1].plot(t_ai, tau_ai, color='tomato', lw=2)
axes[1].set_title(f'Tensión Tangencial $\\tau$ — Barra {BARRA_A+1}')
axes[1].set_xlabel('Tiempo [s]')
axes[1].set_ylabel('$\\tau$ [unid. de fuerza / área]')
axes[1].axhline(0, color='gray', lw=0.8, ls='--')
axes[1].grid(True, alpha=0.4)

# Coordenadas del nodo b
axes[2].plot(t_ai, coord_x_ai, color='forestgreen', lw=2, label='Coordenada X')
axes[2].plot(t_ai, coord_y_ai, color='darkorange',  lw=2, label='Coordenada Y', ls='--')
axes[2].set_title(f'Coordenada Actual del Nodo {NODO_B+1}')
axes[2].set_xlabel('Tiempo [s]')
axes[2].set_ylabel('Coordenada [m]')
axes[2].legend()
axes[2].grid(True, alpha=0.4)

plt.show()

# %%
# ─────────────────────────────────────────────────────────────────────────────
# GRÁFICAS — MODELO a.ii
# ─────────────────────────────────────────────────────────────────────────────

fig, axes = plt.subplots(3, 1, figsize=(12, 12))
fig.suptitle(f'Modelo a.ii — Hasta $t_F$ = {tiempo_colapso_aii:.3f} s', fontsize=14, fontweight='bold')

axes[0].plot(t_aii, sigma_aii, color='royalblue', lw=2)
axes[0].set_title(f'Tensión Normal $\\sigma_n$ — Barra {BARRA_A+1}')
axes[0].set_xlabel('Tiempo [s]')
axes[0].set_ylabel('$\\sigma_n$')
axes[0].axhline(0, color='gray', lw=0.8, ls='--')
axes[0].grid(True, alpha=0.4)

axes[1].plot(t_aii, tau_aii, color='tomato', lw=2)
axes[1].set_title(f'Tensión Tangencial $\\tau$ — Barra {BARRA_A+1}')
axes[1].set_xlabel('Tiempo [s]')
axes[1].set_ylabel('$\\tau$')
axes[1].axhline(0, color='gray', lw=0.8, ls='--')
axes[1].grid(True, alpha=0.4)

axes[2].plot(t_aii, coord_x_aii, color='forestgreen', lw=2, label='Coordenada X')
axes[2].plot(t_aii, coord_y_aii, color='darkorange',  lw=2, label='Coordenada Y', ls='--')
axes[2].set_title(f'Coordenada Actual del Nodo {NODO_B+1}')
axes[2].set_xlabel('Tiempo [s]')
axes[2].set_ylabel('Coordenada [m]')
axes[2].legend()
axes[2].grid(True, alpha=0.4)

plt.show()

# %% [markdown]
# ## ¿Qué ocurre con la tensión tangencial y por qué?
#
# En un reticulado ideal (barras articuladas en todos sus extremos), cada barra trabaja exclusivamente a esfuerzo axial — tracción o compresión. Esto se deduce de tres hipótesis del modelo:
#
# 1. Las cargas externas se aplican **únicamente en los nodos**.
# 2. Los vínculos son **articulaciones perfectas** — no transmiten momentos flectores.
# 3. Las barras son **rectas** y sin peso propio distribuido.
#
# Como consecuencia directa:
# $$\tau = 0 \quad \forall\, t$$

# %% [markdown]
# ## B.iii — Norma Máxima del Vector Desplazamiento
#
# Se calcula para cada instante la norma del desplazamiento de cada nodo respecto a su posición inicial:
#
# $$\|\mathbf{u}_k(t)\| = \sqrt{\bigl(x_k(t) - x_k^0\bigr)^2 + \bigl(y_k(t) - y_k^0\bigr)^2}$$
#
# y se toma el **máximo sobre todos los nodos**. El análisis corre sobre el intervalo común $\left[0,\;\min(t_{F,\text{a.i}},\, t_{F,\text{a.ii}})\right]$ para que la comparación entre modelos sea directa.

# %%
# ─────────────────────────────────────────────────────────────────────────────
# NORMA MÁXIMA DEL VECTOR DESPLAZAMIENTO
# Se evalúa en el intervalo [0, min(t_F_ai, t_F_aii)]
# ─────────────────────────────────────────────────────────────────────────────
tiempo_comun = min(tiempo_colapso_ai, tiempo_colapso_aii)
print(f"Intervalo de análisis común: [0, {tiempo_comun:.4f}] s")

# Función auxiliar: norma de desplazamiento de todos los nodos en cada instante
def norma_max_desplazamiento(solucion, t_limite):
    """
    Para cada instante hasta t_limite, calcula el vector de desplazamiento
    de cada nodo respecto a su posición inicial y devuelve la norma máxima.
    """
    idx_limite = np.searchsorted(solucion.t, t_limite)
    t_rango = solucion.t[:idx_limite+1]
    pos_0   = solucion.y[:num_grados_libertad, 0]  # posición inicial
    
    norma_max_t = np.zeros(idx_limite+1)
    
    for k in range(idx_limite+1):
        pos_k = solucion.y[:num_grados_libertad, k]
        despl = pos_k - pos_0  # desplazamiento de cada gdl
        # Norma por nodo: sqrt(dx^2 + dy^2)
        normas_nodos = np.sqrt(despl[0::2]**2 + despl[1::2]**2)
        norma_max_t[k] = np.max(normas_nodos)
    
    idx_max = np.argmax(norma_max_t)
    return t_rango, norma_max_t, t_rango[idx_max], norma_max_t[idx_max]


t_v_ai,  nm_ai,  t_max_ai,  val_max_ai  = norma_max_desplazamiento(solucion,     tiempo_comun)
t_v_aii, nm_aii, t_max_aii, val_max_aii = norma_max_desplazamiento(solucion_aii, tiempo_comun)

print(f"\nModelo a.i  → Norma máx = {val_max_ai:.4f} m  en  t = {t_max_ai:.4f} s")
print(f"Modelo a.ii → Norma máx = {val_max_aii:.4f} m  en  t = {t_max_aii:.4f} s")
# Out:
# Intervalo de análisis común: [0, 50.0000] s
#
# Modelo a.i  → Norma máx = 9.2315 m  en  t = 28.9790 s
# Modelo a.ii → Norma máx = 9.2963 m  en  t = 23.9740 s

# %%
# ─────────────────────────────────────────────────────────────────────────────
# GRÁFICA COMPARATIVA: norma máxima de desplazamiento
# ─────────────────────────────────────────────────────────────────────────────
plt.figure(figsize=(12, 5))
plt.plot(t_v_ai,  nm_ai,  color='steelblue',   lw=2, label='Modelo a.i  (deformada)')
plt.plot(t_v_aii, nm_aii, color='darkorange',   lw=2, label='Modelo a.ii (referencia)', ls='--')
plt.axvline(t_max_ai,  color='steelblue', lw=1, ls=':', alpha=0.7, label=f'$t_{{max}}$ a.i  = {t_max_ai:.2f} s')
plt.axvline(t_max_aii, color='darkorange', lw=1, ls=':', alpha=0.7, label=f'$t_{{max}}$ a.ii = {t_max_aii:.2f} s')
plt.title('Norma Máxima del Desplazamiento Nodal — Comparación a.i vs a.ii')
plt.xlabel('Tiempo [s]')
plt.ylabel('$\\|\\mathbf{u}\\|_{max}$ [m]')
plt.legend()
plt.grid(True, alpha=0.4)
plt.tight_layout()
plt.savefig('outputs/parte_B_norma_max.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
# ─────────────────────────────────────────────────────────────────────────────
# GRÁFICA COMPARATIVA: tensión normal en barra a — ambos modelos
# ─────────────────────────────────────────────────────────────────────────────
fig, axes = plt.subplots(1, 2, figsize=(14, 5))
fig.suptitle(f'Comparación a.i vs a.ii — Barra {BARRA_A+1} y Nodo {NODO_B+1}', fontsize=13)

# Tensión normal comparada (hasta el mínimo de los dos t_F)
k_comun_ai  = np.searchsorted(solucion.t,     tiempo_comun)
k_comun_aii = np.searchsorted(solucion_aii.t, tiempo_comun)
sigma_ai_c,  _ = calcular_tension_barra_ai (solucion,     BARRA_A, k_comun_ai)
sigma_aii_c, _ = calcular_tension_barra_aii(solucion_aii, BARRA_A, k_comun_aii)

axes[0].plot(solucion.t[:k_comun_ai+1],     sigma_ai_c,  color='steelblue', lw=2, label='a.i')
axes[0].plot(solucion_aii.t[:k_comun_aii+1], sigma_aii_c, color='darkorange', lw=2, label='a.ii', ls='--')
axes[0].set_title(f'Tensión Normal $\\sigma_n$ — Barra {BARRA_A+1}')
axes[0].set_xlabel('Tiempo [s]')
axes[0].set_ylabel('$\\sigma_n$')
axes[0].axhline(0, color='gray', lw=0.8, ls='--')
axes[0].legend()
axes[0].grid(True, alpha=0.4)

# Coordenada Y del nodo b comparada
coord_y_ai_c  = solucion.y[2*NODO_B+1,     :k_comun_ai+1]
coord_y_aii_c = solucion_aii.y[2*NODO_B+1, :k_comun_aii+1]

axes[1].plot(solucion.t[:k_comun_ai+1],     coord_y_ai_c,  color='steelblue', lw=2, label='a.i')
axes[1].plot(solucion_aii.t[:k_comun_aii+1], coord_y_aii_c, color='darkorange', lw=2, label='a.ii', ls='--')
axes[1].set_title(f'Coordenada Y — Nodo {NODO_B+1}')
axes[1].set_xlabel('Tiempo [s]')
axes[1].set_ylabel('Y [m]')
axes[1].legend()
axes[1].grid(True, alpha=0.4)

plt.tight_layout()
plt.savefig('outputs/parte_B_comparacion.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
# ─────────────────────────────────────────────────────────────────────────────
# RESUMEN FINAL
# ─────────────────────────────────────────────────────────────────────────────
display(
    pd.DataFrame({
        "Modelo": ["a.i — Deformaciones Finitas", "a.ii — Pequeños Desplazamientos"],
        "tF [s]": [tiempo_colapso_ai, tiempo_colapso_aii],
        "Norma máx [m]": [val_max_ai, val_max_aii],
        "t (norma máx) [s]": [t_max_ai, t_max_aii],
    }).style
    .set_caption(f"Resumen Parte B — intervalo común [0, {tiempo_comun:.4f}] s")
    .format({"tF [s]": "{:.4f}", "Norma máx [m]": "{:.4f}", "t (norma máx) [s]": "{:.4f}"})
    .hide(axis="index")
)
# Out:
# <style type="text/css">
# </style>
# <table id="T_168bf">
#   <caption>Resumen Parte B — intervalo común [0, 50.0000] s</caption>
#   <thead>
#     <tr>
#       <th id="T_168bf_level0_col0" class="col_heading level0 col0" >Modelo</th>
#       <th id="T_168bf_level0_col1" class="col_heading level0 col1" >tF [s]</th>
#       <th id="T_168bf_level0_col2" class="col_heading level0 col2" >Norma máx [m]</th>
#       <th id="T_168bf_level0_col3" class="col_heading level0 col3" >t (norma máx) [s]</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_168bf_row0_col0" class="data row0 col0" >a.i — Deformaciones Finitas</td>
#       <td id="T_168bf_row0_col1" class="data row0 col1" >50.0000</td>
#       <td id="T_168bf_row0_col2" class="data row0 col2" >9.2315</td>
#       <td id="T_168bf_row0_col3" class="data row0 col3" >28.9790</td>
#     </tr>
#     <tr>
#       <td id="T_168bf_row1_col0" class="data row1 col0" >a.ii — Pequeños Desplazamientos</td>
# ...

# %% [markdown]
# ## Conclusiones — Parte B
#
# ### Diferencias entre los modelos a.i y a.ii
#
# **Tiempo de colapso $t_F$**
#
# Los resultados muestran que los dos modelos producen tiempos de colapso distintos. El modelo **a.i** actualiza la geometría en cada paso de integración: las barras rotan junto con la estructura, y la rigidez efectiva cambia continuamente. El modelo **a.ii**, al fijar la geometría de referencia, mantiene una rigidez constante — lo que implica que no captura el ablandamiento geométrico progresivo ni el reordenamiento de fuerzas internas. Esta diferencia explica la divergencia en $t_F$.
#
# **Evolución de tensiones y coordenadas**
#
# Para instantes tempranos ($t \ll t_F$), ambos modelos producen tensiones normales y trayectorias nodales casi idénticas: la estructura aún no ha acumulado desplazamientos significativos y la hipótesis lineal de a.ii es una buena aproximación. A medida que la deformación crece, las curvas se separan progresivamente. Cerca de $t_F$, la tensión en la barra $a$ y la trayectoria del nodo $b$ en a.i reflejan el acoplamiento no lineal geometría–fuerza, mientras que a.ii subestima (o sobreestima) los efectos porque opera sobre una geometría "congelada".
#
# **Norma máxima de desplazamiento**
#
# La norma máxima del vector desplazamiento confirma esta tendencia: en el intervalo común $[0,\, \min(t_{F,\text{a.i}},\, t_{F,\text{a.ii}})]$, ambos modelos parten del mismo valor nulo y divergen conforme avanza el tiempo. El modelo a.i alcanza normas mayores porque la geometría deformada redirige las fuerzas de modo que pueden amplificar el movimiento.
#
# ### ¿Cuál modelo es más adecuado?
#
# El **modelo a.i (deformaciones finitas)** es el más adecuado para este problema. Las barras del reticulado experimentan desplazamientos del orden de varios metros antes del colapso — no son pequeños frente a las dimensiones de la estructura (barras de longitud 5–14 m). En este régimen, ignorar los cambios de geometría introduce un error sistemático creciente.
#
# El **modelo a.ii (pequeños desplazamientos)** es válido únicamente mientras los desplazamientos sean pequeños frente a la longitud característica de las barras. En la práctica, esto corresponde al intervalo inicial de la simulación donde ambas curvas se superponen. Una regla práctica: si $\|\mathbf{u}\|_{\max} / L_{\text{ref}} \ll 1$ (por ejemplo $< 5\,\%$), a.ii es una aproximación aceptable. Pasado ese umbral, solo a.i captura correctamente la respuesta.

# %% [markdown]
# ### Parte C: Incorporación de Dispositivo Amortiguador
#
# Modifique el programa desarrollado para la situación $a.i$ (dirección de las fuerzas en la configuración deformada) para incorporar, en el nodo $c$, una esfera sólida de radio $r_{esf}$ que se desplaza dentro de un dispositivo constituido por un recipiente con líquido y aire (ver esquema en figura correspondiente).
#
# Este dispositivo actúa como un **mecanismo amortiguador** del movimiento de la esfera y, por lo tanto, del reticulado.
#
# ![fluido](Imagenes/fluido.png)
#
#
# **Simplificaciones:**
# * Se considera únicamente la acción en la **dirección vertical** (despreciando la resistencia del fluido en dirección horizontal y al giro).
# * Se adopta que la fuerza generada por el contacto de la esfera con el aire en el dispositivo es despreciable.
#
# **Cálculo de la Fuerza de Arrastre (Drag Force)**
# Esta acción se entiende como una fuerza externa aplicada al sistema del reticulado y se calcula como:
#
# $$F_a = -\frac{1}{2} \rho_{fl} C_d A_R |u| u$$
#
# Donde:
# * $\rho_{fl}$: Densidad del fluido.
# * $C_d$: Coeficiente de arrastre, que depende de la forma del objeto (esfera) y del número de Reynolds ($Re$). Para un régimen de flujo de aproximadamente $10^3 < Re < 2 \times 10^5$, **se adopta $C_d$ constante e igual a $0.47$**.
# * $A_R$: Superficie de referencia, que es la proyección de la parte sumergida en un plano perpendicular al movimiento.
# * $u$: Velocidad de la esfera en dirección vertical.
#
# **Condiciones de Inmersión (Área $A_R$)**
# Esta área define una etapa de transición en el valor de la fuerza. Se deben considerar tres condiciones sobre la esfera dependiendo de su nivel de inmersión (asumiendo que esto no modifica el $C_d$ adoptado):
# 1. Esfera **completamente fuera** del fluido.
# 2. Esfera **parcialmente sumergida**, desde un polo hasta la mitad.
# 3. Esfera sumergida **desde la mitad y hasta su inmersión completa**.
#
# > *Nota:* Esta transición contribuye a la robustez de la resolución numérica. El nivel de la superficie libre del fluido es fijo y está dado por la cota $h_{SL}$.
#
# ---
#
# ### Análisis de Resultados con Amortiguador
#
# En el problema con el dispositivo amortiguador, analice lo siguiente:
#
# **1. Comparaciones:**
# * Compare los resultados de $t_F$ obtenidos (con y sin amortiguador).
# * Compare la evolución temporal de la **tensión en la barra $a$**.
# * Compare la evolución de la **coordenada actual del nodo $b$**.
# * Compare la **norma del vector desplazamiento máxima** y el instante en que se produce.
#
# **2. Conclusiones y Experimentación:**
# * **¿Qué efecto tiene el dispositivo de amortiguamiento en la deformación de la estructura a lo largo del tiempo?**
# * **Experimente y grafique** resultados convenientes variando los parámetros $r_{esf}$ y $\rho_{fl}$ para analizar su influencia en el problema.

# %%
# ─────────────────────────────────────────────────────────────────────────────
# PARÁMETROS DEL AMORTIGUADOR
# ─────────────────────────────────────────────────────────────────────────────
densidad_fluido  = 3.0    # Densidad del fluido
radio_esfera   = 1.5    # Radio de la esfera [m]
cota_superficie_libre    = 25.0   # Cota de la superficie libre del fluido [m]
Cd      = 0.47   # Coeficiente de arrastre (esfera en régimen intermedio)
NODO_C  = 9      # Índice Python del nodo c=10

print(f"Parámetros cargados: densidad_fluido={densidad_fluido}, radio_esfera={radio_esfera}, cota_superficie_libre={cota_superficie_libre}, Cd={Cd}")
# Out:
# Parámetros cargados: densidad_fluido=3.0, radio_esfera=1.5, cota_superficie_libre=25.0, Cd=0.47

# %% [markdown]
# ## C.1 — Área de Referencia $A_R$ según el nivel de inmersión
#
# $A_R$ es la proyección de la parte sumergida de la esfera en el plano perpendicular al movimiento. Varía según la posición vertical $y_c$ del centro respecto a la superficie libre $h_{SL}$:
#
# | Condición | $A_R$ |
# |:----------|:------|
# | Polo inferior **sobre** $h_{SL}$ — completamente fuera | $0$ |
# | **Inmersión parcial** — $h_{SL}$ corta la esfera | $\pi\,(r_{\text{esf}}^2 - \delta^2)$,\; $\delta = h_{SL} - y_c$ |
# | Polo superior **bajo** $h_{SL}$ — completamente sumergida | $\pi\, r_{\text{esf}}^2$ |
#
# La transición continua (sin saltos en $A_R$) mejora la estabilidad numérica del integrador BDF.

# %%
# ─────────────────────────────────────────────────────────────────────────────
# FUNCIÓN: Área de referencia A_R según nivel de inmersión
# y_c  : coordenada Y actual del centro de la esfera (= posición Y del nodo c)
# ─────────────────────────────────────────────────────────────────────────────
def calcular_AR(y_c, radio_esfera, cota_superficie_libre):
    """
    Devuelve el área de referencia A_R de la esfera según su nivel de inmersión.
    
    La esfera está centrada en y_c. La superficie libre del fluido está en cota_superficie_libre.
    
    Regímenes:
    - Polo inferior de la esfera aún por encima de cota_superficie_libre  → A_R = 0
    - Centro entre cota_superficie_libre y cota_superficie_libre - radio_esfera (mitad superior) → A_R = pi*(r^2 - d^2),  d = y_c - cota_superficie_libre (< 0 cuando sale)
    - Centro entre cota_superficie_libre - radio_esfera y cota_superficie_libre - 2*radio_esfera        → A_R = pi*(r^2 - (y_c - (cota_superficie_libre - radio_esfera))^2)
    - Polo superior por debajo de cota_superficie_libre                   → A_R = pi*r^2
    """
    # Límites de las zonas
    y_polo_inf  = y_c - radio_esfera   # coordenada del polo inferior
    y_ecuador   = y_c           # ecuador = centro
    y_polo_sup  = y_c + radio_esfera   # coordenada del polo superior

    if y_polo_inf >= cota_superficie_libre:
        # --- Estado 1: completamente fuera ---
        return 0.0

    elif y_polo_sup <= cota_superficie_libre:
        # --- Estado 4: completamente sumergida ---
        return np.pi * radio_esfera**2

    else:
        # Inmersión parcial: el plano cota_superficie_libre corta la esfera
        # Distancia del centro a la superficie libre (positiva si centro abajo)
        delta = cota_superficie_libre - y_c   # > 0 → centro bajo la sup.libre; < 0 → centro sobre la sup.libre
        # Radio del círculo de intersección con la superficie libre
        # r_corte^2 = radio_esfera^2 - delta^2  (siempre >= 0 en este rango)
        r_corte_sq = radio_esfera**2 - delta**2
        r_corte_sq = max(r_corte_sq, 0.0)  # protección numérica
        return np.pi * r_corte_sq


# ─────────────────────────────────────────────────────────────────────────────
# FUNCIÓN: Fuerza de arrastre en dirección vertical
# u_y   : velocidad vertical del nodo c
# y_c   : posición vertical actual del nodo c
# ─────────────────────────────────────────────────────────────────────────────
def fuerza_arrastre(u_y, y_c, densidad_fluido, Cd, radio_esfera, cota_superficie_libre):
    """
    F_a = -0.5 * densidad_fluido * Cd * A_R * |u_y| * u_y
    Retorna la fuerza escalar en Y (negativa si opone al movimiento).
    """
    AR = calcular_AR(y_c, radio_esfera, cota_superficie_libre)
    return -0.5 * densidad_fluido * Cd * AR * abs(u_y) * u_y


# ── Verificación rápida de los regímenes ──
_casos = [(27.0,"Completamente fuera"),(25.0,"Ecuador en sup. libre"),
          (24.0,"Parcialmente sumergida"),(23.5,"Completamente sumergida")]
display(
    pd.DataFrame({
        "y_c [m]":    [yc for yc,_ in _casos],
        "Condición":  [d  for _,d  in _casos],
        "A_R [m²]":   [calcular_AR(yc, radio_esfera, cota_superficie_libre) for yc,_ in _casos],
    }).style
    .set_caption("Verificación A_R — radio_esfera=1.5 m, h_SL=25 m")
    .format({"y_c [m]": "{:.1f}", "A_R [m²]": "{:.4f}"})
    .hide(axis="index")
)
# Out:
# <style type="text/css">
# </style>
# <table id="T_94ef2">
#   <caption>Verificación A_R — radio_esfera=1.5 m, h_SL=25 m</caption>
#   <thead>
#     <tr>
#       <th id="T_94ef2_level0_col0" class="col_heading level0 col0" >y_c [m]</th>
#       <th id="T_94ef2_level0_col1" class="col_heading level0 col1" >Condición</th>
#       <th id="T_94ef2_level0_col2" class="col_heading level0 col2" >A_R [m²]</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_94ef2_row0_col0" class="data row0 col0" >27.0</td>
#       <td id="T_94ef2_row0_col1" class="data row0 col1" >Completamente fuera</td>
#       <td id="T_94ef2_row0_col2" class="data row0 col2" >0.0000</td>
#     </tr>
#     <tr>
#       <td id="T_94ef2_row1_col0" class="data row1 col0" >25.0</td>
#       <td id="T_94ef2_row1_col1" class="data row1 col1" >Ecuador en sup. libre</td>
#       <td id="T_94ef2_row1_col2" class="data row1 col2" >7.0686</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# ## C.2 — Función de Derivadas con Amortiguador
#
# Se modifica `calcular_derivadas` (modelo a.i) para sumar la fuerza de arrastre al GDL Y del nodo $c$.

# %%
# ─────────────────────────────────────────────────────────────────────────────
# FUNCIÓN MOTOR — Modelo a.i CON amortiguador
# Idéntica a calcular_derivadas, pero suma F_arrastre en el GDL Y del nodo c
# ─────────────────────────────────────────────────────────────────────────────
def calcular_derivadas_amort(t, Y,
                              densidad_fluido=densidad_fluido, Cd=Cd,
                              radio_esfera=radio_esfera, cota_superficie_libre=cota_superficie_libre):
    posiciones = Y[:num_grados_libertad]
    velocidades = Y[num_grados_libertad:]

    F_interna = np.zeros(num_grados_libertad)

    for b in range(num_barras):
        nodo_i = conectividad[b, 0]
        nodo_j = conectividad[b, 1]

        xi_a, yi_a = posiciones[2*nodo_i],   posiciones[2*nodo_i+1]
        xj_a, yj_a = posiciones[2*nodo_j],   posiciones[2*nodo_j+1]

        dx_a = xj_a - xi_a
        dy_a = yj_a - yi_a
        L_actual = np.sqrt(dx_a**2 + dy_a**2) + 1e-9

        fuerza_resorte = ((elasticidad * area) / longitudes_iniciales[b]) * (L_actual - longitudes_iniciales[b])
        Fx = fuerza_resorte * (dx_a / L_actual)
        Fy = fuerza_resorte * (dy_a / L_actual)

        F_interna[2*nodo_i]     += Fx
        F_interna[2*nodo_i + 1] += Fy
        F_interna[2*nodo_j]     -= Fx
        F_interna[2*nodo_j + 1] -= Fy

    # ── Fuerza de arrastre en el nodo c (solo componente Y) ──
    y_c   = posiciones[2*NODO_C + 1]      # posición Y actual del nodo c
    u_y   = velocidades[2*NODO_C + 1]     # velocidad Y actual del nodo c
    F_drag = fuerza_arrastre(u_y, y_c, densidad_fluido, Cd, radio_esfera, cota_superficie_libre)

    # F_externa ya contiene la carga P; sumamos el arrastre como fuerza adicional
    F_total = F_externa.copy()
    F_total[2*NODO_C + 1] += F_drag

    F_neta = F_total + F_interna
    F_neta[gdl_restringidos] = 0.0

    aceleraciones = np.where(masas_nodales > 0, F_neta / masas_nodales, 0.0)

    return np.concatenate((velocidades, aceleraciones))


print("Función calcular_derivadas_amort definida correctamente.")
# Out:
# Función calcular_derivadas_amort definida correctamente.

# %% [markdown]
# ## C.3 — Simulación con Amortiguador
#
# Se integra el modelo **a.i** con la fuerza de arrastre activa en el nodo $c = 10$. Las condiciones iniciales y el método BDF son idénticos al caso sin amortiguador para que la comparación sea directa.

# %%
print("Simulando modelo a.i CON amortiguador...")

solucion_amortiguada = solve_ivp(
    fun=calcular_derivadas_amort,
    t_span=(0.0, 50.0),
    y0=estado_inicial,
    t_eval=np.linspace(0, 50, 1000),
    method='BDF'
)

if solucion_amortiguada.success:
    print("¡Simulación con amortiguador terminada con éxito!")
else:
    print("Error:", solucion_amortiguada.message)
# Out:
# Simulando modelo a.i CON amortiguador...
# ¡Simulación con amortiguador terminada con éxito!

# %% [markdown]
# ## C.4 — Tiempo de Colapso $t_F$ con Amortiguador
#
# Se reutiliza `detectar_tF` de la Parte B. Si el amortiguador es suficientemente fuerte, la estructura puede no alcanzar el estado límite en $[0,\, 50]$ s y se adopta $t_F = t_{F,\text{Max}}$.

# %%
# Reutilizamos directamente la función detectar_tF de la Parte B
tiempo_colapso_amort, paso_colapso_amort, triangulo_critico_amort = detectar_tF(solucion_amortiguada, triangulos)

display(
    pd.DataFrame({
        "Configuración": ["Sin amortiguador (a.i)", "Con amortiguador"],
        "tF [s]": [tiempo_colapso_ai, tiempo_colapso_amort],
        "Triángulo crítico": [
            str(tuple(n+1 for n in triangulo_critico_ai)) if triangulo_critico_ai else "—",
            str(tuple(n+1 for n in triangulo_critico_amort)) if triangulo_critico_amort else "—"
        ]
    }).style
    .set_caption("C.4 — Comparación de tiempos de colapso")
    .format({"tF [s]": "{:.4f}"})
    .hide(axis="index")
)
# Out:
# <style type="text/css">
# </style>
# <table id="T_22f7c">
#   <caption>C.4 — Comparación de tiempos de colapso</caption>
#   <thead>
#     <tr>
#       <th id="T_22f7c_level0_col0" class="col_heading level0 col0" >Configuración</th>
#       <th id="T_22f7c_level0_col1" class="col_heading level0 col1" >tF [s]</th>
#       <th id="T_22f7c_level0_col2" class="col_heading level0 col2" >Triángulo crítico</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_22f7c_row0_col0" class="data row0 col0" >Sin amortiguador (a.i)</td>
#       <td id="T_22f7c_row0_col1" class="data row0 col1" >50.0000</td>
#       <td id="T_22f7c_row0_col2" class="data row0 col2" >—</td>
#     </tr>
#     <tr>
#       <td id="T_22f7c_row1_col0" class="data row1 col0" >Con amortiguador</td>
#       <td id="T_22f7c_row1_col1" class="data row1 col1" >50.0000</td>
#       <td id="T_22f7c_row1_col2" class="data row1 col2" >—</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## C.5 — Comparación Sin / Con Amortiguador
#
# Se comparan sobre el intervalo común $[0,\, \min(t_{F,\text{sin}},\, t_{F,\text{con}})]$:
#
# - Tensión normal $\sigma_n$ en la barra $a = 8$
# - Coordenadas actuales del nodo $b = 10$
# - Norma máxima de desplazamiento nodal

# %%
# ─────────────────────────────────────────────────────────────────────────────
# INTERVALO COMÚN: [0, min(tiempo_colapso_ai, tiempo_colapso_amort)]
# ─────────────────────────────────────────────────────────────────────────────
tiempo_comun_amort = min(tiempo_colapso_ai, tiempo_colapso_amort)
print(f"Intervalo de comparación: [0, {tiempo_comun_amort:.4f}] s")

k_comun_ai    = np.searchsorted(solucion.t,       tiempo_comun_amort)
k_comun_amort = np.searchsorted(solucion_amortiguada.t, tiempo_comun_amort)

# ── Tensiones en barra a ──
sigma_sin,  _ = calcular_tension_barra_ai(solucion,      BARRA_A, k_comun_ai)
sigma_con,  _ = calcular_tension_barra_ai(solucion_amortiguada, BARRA_A, k_comun_amort)

t_sin = solucion.t[:k_comun_ai+1]
t_con = solucion_amortiguada.t[:k_comun_amort+1]

# ── Coordenadas del nodo b ──
coord_x_sin = solucion.y[2*NODO_B,       :k_comun_ai+1]
coord_y_sin = solucion.y[2*NODO_B+1,     :k_comun_ai+1]
coord_x_con = solucion_amortiguada.y[2*NODO_B,   :k_comun_amort+1]
coord_y_con = solucion_amortiguada.y[2*NODO_B+1, :k_comun_amort+1]

# ── Normas máximas ──
_, nm_sin, t_max_sin, val_max_sin = norma_max_desplazamiento(solucion,      tiempo_comun_amort)
_, nm_con, t_max_con, val_max_con = norma_max_desplazamiento(solucion_amortiguada, tiempo_comun_amort)

print(f"\n  Norma máx sin amort: {val_max_sin:.4f} m  en t = {t_max_sin:.4f} s")
print(f"  Norma máx con amort: {val_max_con:.4f} m  en t = {t_max_con:.4f} s")
# Out:
# Intervalo de comparación: [0, 50.0000] s
#
#   Norma máx sin amort: 9.2315 m  en t = 28.9790 s
#   Norma máx con amort: 8.9670 m  en t = 28.7788 s

# %%
# ─────────────────────────────────────────────────────────────────────────────
# FIGURA 1: Tensión Normal en Barra a — sin vs con amortiguador
# ─────────────────────────────────────────────────────────────────────────────
fig, axes = plt.subplots(1, 2, figsize=(14, 5))
fig.suptitle(f'Comparación Sin / Con Amortiguador — Barra {BARRA_A+1}', fontsize=13)

axes[0].plot(t_sin, sigma_sin, color='steelblue',  lw=2, label='Sin amortiguador')
axes[0].plot(t_con, sigma_con, color='crimson',     lw=2, label='Con amortiguador', ls='--')
axes[0].set_title('Tensión Normal $\\sigma_n$')
axes[0].set_xlabel('Tiempo [s]')
axes[0].set_ylabel('$\\sigma_n$')
axes[0].axhline(0, color='gray', lw=0.8, ls=':')
axes[0].legend()
axes[0].grid(True, alpha=0.4)

# Diferencia absoluta
# Interpolamos para tener la misma grilla de tiempo
sigma_sin_interp = np.interp(t_con, t_sin, sigma_sin)
axes[1].plot(t_con, sigma_con - sigma_sin_interp, color='darkorchid', lw=2)
axes[1].set_title('Diferencia $\\sigma_{con} - \\sigma_{sin}$')
axes[1].set_xlabel('Tiempo [s]')
axes[1].set_ylabel('$\\Delta\\sigma_n$')
axes[1].axhline(0, color='gray', lw=0.8, ls=':')
axes[1].grid(True, alpha=0.4)

plt.tight_layout()
plt.savefig('outputs/parte_C_tension.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
# ─────────────────────────────────────────────────────────────────────────────
# FIGURA 2: Coordenada Y del Nodo b — sin vs con amortiguador
# ─────────────────────────────────────────────────────────────────────────────
fig, axes = plt.subplots(1, 2, figsize=(14, 5))
fig.suptitle(f'Coordenada Actual del Nodo {NODO_B+1} — Sin / Con Amortiguador', fontsize=13)

axes[0].plot(t_sin, coord_x_sin, color='steelblue',  lw=2, label='X sin amort')
axes[0].plot(t_con, coord_x_con, color='crimson',     lw=2, label='X con amort', ls='--')
axes[0].set_title('Coordenada X')
axes[0].set_xlabel('Tiempo [s]')
axes[0].set_ylabel('X [m]')
axes[0].legend()
axes[0].grid(True, alpha=0.4)

axes[1].plot(t_sin, coord_y_sin, color='steelblue',  lw=2, label='Y sin amort')
axes[1].plot(t_con, coord_y_con, color='crimson',     lw=2, label='Y con amort', ls='--')
axes[1].axhline(cota_superficie_libre, color='navy', lw=1.2, ls=':', label=f'$h_{{SL}}={cota_superficie_libre}$')
axes[1].set_title('Coordenada Y')
axes[1].set_xlabel('Tiempo [s]')
axes[1].set_ylabel('Y [m]')
axes[1].legend()
axes[1].grid(True, alpha=0.4)

plt.tight_layout()
plt.savefig('outputs/parte_C_coordenadas.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
# ─────────────────────────────────────────────────────────────────────────────
# FIGURA 3: Norma Máxima de Desplazamiento — sin vs con amortiguador
# ─────────────────────────────────────────────────────────────────────────────
t_v_sin, nm_v_sin, _, _ = norma_max_desplazamiento(solucion,       tiempo_comun_amort)
t_v_con, nm_v_con, _, _ = norma_max_desplazamiento(solucion_amortiguada, tiempo_comun_amort)

plt.figure(figsize=(12, 5))
plt.plot(t_v_sin, nm_v_sin, color='steelblue', lw=2, label='Sin amortiguador')
plt.plot(t_v_con, nm_v_con, color='crimson',   lw=2, label='Con amortiguador', ls='--')
plt.axvline(t_max_sin, color='steelblue', lw=1, ls=':', alpha=0.8,
            label=f'$t_{{max}}$ sin = {t_max_sin:.2f} s')
plt.axvline(t_max_con, color='crimson',   lw=1, ls=':', alpha=0.8,
            label=f'$t_{{max}}$ con = {t_max_con:.2f} s')
plt.title('Norma Máxima del Desplazamiento Nodal')
plt.xlabel('Tiempo [s]')
plt.ylabel('$\\|\\mathbf{u}\\|_{max}$ [m]')
plt.legend()
plt.grid(True, alpha=0.4)
plt.tight_layout()
plt.savefig('outputs/parte_C_norma.png', dpi=150, bbox_inches='tight')
plt.show()

print(f"\nNorma máx SIN amort: {val_max_sin:.4f} m  en t = {t_max_sin:.4f} s")
print(f"Norma máx CON amort: {val_max_con:.4f} m  en t = {t_max_con:.4f} s")
# Out:
# Norma máx SIN amort: 9.2315 m  en t = 28.9790 s
# Norma máx CON amort: 8.9670 m  en t = 28.7788 s

# %% [markdown]
# ## C.6 — Evolución del Área de Referencia $A_R$ y la Fuerza de Arrastre
#
# Gráfica auxiliar que muestra el nivel de inmersión y la fuerza de arrastre a lo largo del tiempo para verificar la correcta implementación.

# %%
# ─────────────────────────────────────────────────────────────────────────────
# Calculamos A_R y F_drag a lo largo del tiempo (solución CON amortiguador)
# ─────────────────────────────────────────────────────────────────────────────
n_t = len(solucion_amortiguada.t)
AR_t     = np.zeros(n_t)
Fdrag_t  = np.zeros(n_t)
yc_t     = solucion_amortiguada.y[2*NODO_C + 1, :]
vy_c_t   = solucion_amortiguada.y[num_grados_libertad + 2*NODO_C + 1, :]  # velocidad Y del nodo c

for k in range(n_t):
    AR_t[k]    = calcular_AR(yc_t[k], radio_esfera, cota_superficie_libre)
    Fdrag_t[k] = fuerza_arrastre(vy_c_t[k], yc_t[k], densidad_fluido, Cd, radio_esfera, cota_superficie_libre)

fig, axes = plt.subplots(3, 1, figsize=(12, 10))
fig.suptitle('Evolución del Amortiguador — Nodo c=10', fontsize=13)

axes[0].plot(solucion_amortiguada.t, yc_t, color='steelblue', lw=2)
axes[0].axhline(cota_superficie_libre,        color='navy',   lw=1.2, ls='--', label=f'$h_{{SL}}$ = {cota_superficie_libre}')
axes[0].axhline(cota_superficie_libre - radio_esfera, color='green', lw=1.0, ls=':',  label=f'$h_{{SL}} - r$ = {cota_superficie_libre-radio_esfera}')
axes[0].axhline(cota_superficie_libre + radio_esfera, color='orange',lw=1.0, ls=':',  label=f'$h_{{SL}} + r$ = {cota_superficie_libre+radio_esfera}')
axes[0].set_title('Posición Y del nodo c')
axes[0].set_ylabel('Y [m]')
axes[0].legend(fontsize=8)
axes[0].grid(True, alpha=0.4)

axes[1].plot(solucion_amortiguada.t, AR_t, color='teal', lw=2)
axes[1].axhline(np.pi*radio_esfera**2, color='gray', lw=1, ls='--', label=f'$\\pi r^2$ = {np.pi*radio_esfera**2:.3f}')
axes[1].set_title('Área de Referencia $A_R$')
axes[1].set_ylabel('$A_R$ [m²]')
axes[1].legend(fontsize=8)
axes[1].grid(True, alpha=0.4)

axes[2].plot(solucion_amortiguada.t, Fdrag_t, color='crimson', lw=2)
axes[2].axhline(0, color='gray', lw=0.8, ls=':')
axes[2].set_title('Fuerza de Arrastre $F_a$ (componente Y)')
axes[2].set_xlabel('Tiempo [s]')
axes[2].set_ylabel('$F_a$ [N]')
axes[2].grid(True, alpha=0.4)

plt.tight_layout()
plt.savefig('outputs/parte_C_arrastre.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## C.7 — Experimentación: Variación de $r_{esf}$ y $\rho_{fl}$
#
# Exploramos cómo afectan estos parámetros al comportamiento de la estructura.

# %%
# ─────────────────────────────────────────────────────────────────────────────
# FUNCIÓN AUXILIAR: simula y devuelve norma max y t_F para dados rho y r
# ─────────────────────────────────────────────────────────────────────────────
def simular_con_params(rho_fl_p, r_esf_p, h_SL_p=cota_superficie_libre, Cd_p=Cd):
    def deriv(t, Y):
        return calcular_derivadas_amort(t, Y,
                                        densidad_fluido=rho_fl_p, Cd=Cd_p,
                                        radio_esfera=r_esf_p,  cota_superficie_libre=h_SL_p)
    sol = solve_ivp(deriv, (0, 50), estado_inicial,
                    t_eval=np.linspace(0, 50, 1000), method='BDF')
    return sol


# ─────────────────────────────────────────────────────────────────────────────
# BARRIDO 1: Variación de radio_esfera (densidad fija = densidad_fluido nominal)
# ─────────────────────────────────────────────────────────────────────────────
radios   = [0.5, 1.0, 1.5, 2.0, 2.5]
colores  = ['tab:blue', 'tab:orange', 'tab:green', 'tab:red', 'tab:purple']

print("Barrido de radio_esfera (esto puede tardar ~1 min)...")
fig, axes = plt.subplots(1, 2, figsize=(14, 5))
fig.suptitle(f'Variación de $r_{{esf}}$ (con $\\rho_{{fl}}={densidad_fluido}$)', fontsize=13)

# Referencia sin amortiguador
axes[0].plot(solucion.t, solucion.y[2*NODO_B+1, :],
             color='black', lw=1.5, ls='--', label='Sin amort')
axes[1].plot(solucion.t, solucion.y[2*NODO_B+1, :],
             color='black', lw=1.5, ls='--', label='Sin amort')

for r_p, col in zip(radios, colores):
    sol_p = simular_con_params(densidad_fluido, r_p)
    if sol_p.success:
        tF_p, _, _ = detectar_tF(sol_p, triangulos)
        axes[0].plot(sol_p.t, sol_p.y[2*NODO_B+1, :],
                     color=col, lw=2, label=f'r={r_p} (tF={tF_p:.1f}s)')
        # Tensión en barra a
        k_end = len(sol_p.t) - 1
        sig_p, _ = calcular_tension_barra_ai(sol_p, BARRA_A, k_end)
        axes[1].plot(sol_p.t, sig_p,
                     color=col, lw=2, label=f'r={r_p}')
        print(f"  radio_esfera={r_p:.1f} → t_F={tF_p:.2f} s")

axes[0].set_title(f'Coordenada Y — Nodo {NODO_B+1}')
axes[0].set_xlabel('Tiempo [s]')
axes[0].set_ylabel('Y [m]')
axes[0].legend(fontsize=8)
axes[0].grid(True, alpha=0.4)

axes[1].set_title(f'Tensión Normal — Barra {BARRA_A+1}')
axes[1].set_xlabel('Tiempo [s]')
axes[1].set_ylabel('$\\sigma_n$')
axes[1].legend(fontsize=8)
axes[1].grid(True, alpha=0.4)

plt.tight_layout()
plt.savefig('outputs/parte_C_var_radio.png', dpi=150, bbox_inches='tight')
plt.show()
# Out:
# Barrido de radio_esfera (esto puede tardar ~1 min)...
#   radio_esfera=0.5 → t_F=50.00 s
#   radio_esfera=1.0 → t_F=50.00 s
#   radio_esfera=1.5 → t_F=50.00 s
#   radio_esfera=2.0 → t_F=50.00 s
#   radio_esfera=2.5 → t_F=50.00 s

# %%
# ─────────────────────────────────────────────────────────────────────────────
# BARRIDO 2: Variación de densidad_fluido (radio fijo = radio_esfera nominal)
# ─────────────────────────────────────────────────────────────────────────────
densidades = [0.5, 1.0, 3.0, 6.0, 10.0]
colores2   = ['tab:blue', 'tab:orange', 'tab:green', 'tab:red', 'tab:purple']

print("Barrido de densidad_fluido (esto puede tardar ~1 min)...")
fig, axes = plt.subplots(1, 2, figsize=(14, 5))
fig.suptitle(f'Variación de $\\rho_{{fl}}$ (con $r_{{esf}}={radio_esfera}$)', fontsize=13)

axes[0].plot(solucion.t, solucion.y[2*NODO_B+1, :],
             color='black', lw=1.5, ls='--', label='Sin amort')
axes[1].plot(solucion.t, solucion.y[2*NODO_B+1, :],
             color='black', lw=1.5, ls='--', label='Sin amort')

for rho_p, col in zip(densidades, colores2):
    sol_p = simular_con_params(rho_p, radio_esfera)
    if sol_p.success:
        tF_p, _, _ = detectar_tF(sol_p, triangulos)
        axes[0].plot(sol_p.t, sol_p.y[2*NODO_B+1, :],
                     color=col, lw=2, label=f'ρ={rho_p} (tF={tF_p:.1f}s)')
        k_end = len(sol_p.t) - 1
        sig_p, _ = calcular_tension_barra_ai(sol_p, BARRA_A, k_end)
        axes[1].plot(sol_p.t, sig_p,
                     color=col, lw=2, label=f'ρ={rho_p}')
        print(f"  densidad_fluido={rho_p:.1f} → t_F={tF_p:.2f} s")

axes[0].set_title(f'Coordenada Y — Nodo {NODO_B+1}')
axes[0].set_xlabel('Tiempo [s]')
axes[0].set_ylabel('Y [m]')
axes[0].legend(fontsize=8)
axes[0].grid(True, alpha=0.4)

axes[1].set_title(f'Tensión Normal — Barra {BARRA_A+1}')
axes[1].set_xlabel('Tiempo [s]')
axes[1].set_ylabel('$\\sigma_n$')
axes[1].legend(fontsize=8)
axes[1].grid(True, alpha=0.4)

plt.tight_layout()
plt.savefig('outputs/parte_C_var_densidad.png', dpi=150, bbox_inches='tight')
plt.show()
# Out:
# Barrido de densidad_fluido (esto puede tardar ~1 min)...
#   densidad_fluido=0.5 → t_F=50.00 s
#   densidad_fluido=1.0 → t_F=50.00 s
#   densidad_fluido=3.0 → t_F=50.00 s
#   densidad_fluido=6.0 → t_F=50.00 s
#   densidad_fluido=10.0 → t_F=50.00 s

# %%
# ─────────────────────────────────────────────────────────────────────────────
# RESUMEN FINAL — PARTE C
# ─────────────────────────────────────────────────────────────────────────────
display(
    pd.DataFrame({
        "Configuración": ["Sin amortiguador (a.i)", "Con amortiguador"],
        "tF [s]": [tiempo_colapso_ai, tiempo_colapso_amort],
        "Norma máx [m]": [val_max_sin, val_max_con],
        "t (norma máx) [s]": [t_max_sin, t_max_con],
    }).style
    .set_caption(
        f"Resumen Parte C — ρfl={densidad_fluido}, r_esf={radio_esfera} m, h_SL={cota_superficie_libre} m"
    )
    .format({"tF [s]": "{:.4f}", "Norma máx [m]": "{:.4f}", "t (norma máx) [s]": "{:.4f}"})
    .hide(axis="index")
)
# Out:
# <style type="text/css">
# </style>
# <table id="T_881e8">
#   <caption>Resumen Parte C — ρfl=3.0, r_esf=1.5 m, h_SL=25.0 m</caption>
#   <thead>
#     <tr>
#       <th id="T_881e8_level0_col0" class="col_heading level0 col0" >Configuración</th>
#       <th id="T_881e8_level0_col1" class="col_heading level0 col1" >tF [s]</th>
#       <th id="T_881e8_level0_col2" class="col_heading level0 col2" >Norma máx [m]</th>
#       <th id="T_881e8_level0_col3" class="col_heading level0 col3" >t (norma máx) [s]</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_881e8_row0_col0" class="data row0 col0" >Sin amortiguador (a.i)</td>
#       <td id="T_881e8_row0_col1" class="data row0 col1" >50.0000</td>
#       <td id="T_881e8_row0_col2" class="data row0 col2" >9.2315</td>
#       <td id="T_881e8_row0_col3" class="data row0 col3" >28.9790</td>
#     </tr>
#     <tr>
#       <td id="T_881e8_row1_col0" class="data row1 col0" >Con amortiguador</td>
# ...

# %% [markdown]
# ## Conclusiones — Parte C
#
# ### Efecto del amortiguador sobre $t_F$
# El dispositivo de arrastre frena el movimiento de la estructura, de modo que en general se espera que **$t_{F,\text{con}} > t_{F,\text{sin}}$**: la estructura tarda más tiempo en alcanzar la condición de cruce de barras. Cuanto mayor sea la fuerza de arrastre (mayor $\rho_{fl}$ o $r_{esf}$), más pronunciado es este efecto. Si el amortiguamiento es suficientemente grande, la estructura puede nunca llegar al estado límite en el intervalo $[0, t_{F,Max}]$.
#
# ### Efecto sobre las tensiones
# La tensión en la barra $a$ se ve modificada: el amortiguador introduce una fuerza adicional que modifica el equilibrio de fuerzas en el nodo $c$ y se propaga a toda la estructura. En general se observa una **reducción de la amplitud de oscilación** de la tensión y una tendencia a estabilizarse en un valor de equilibrio estático más rápidamente.
#
# ### Efecto sobre las coordenadas del nodo $b$
# La coordenada Y del nodo $b$ muestra un comportamiento **menos oscilatorio** con el amortiguador. El sistema pierde energía más rápido, y el nodo converge hacia una posición de equilibrio en menor tiempo.
#
# ### Norma máxima de desplazamiento
# El amortiguador reduce el desplazamiento máximo alcanzado por cualquier nodo de la estructura. La norma máxima con amortiguador es menor que sin él, y se alcanza generalmente más tarde, lo que evidencia la disipación de energía.
#
# ### Influencia de $r_{esf}$ y $\rho_{fl}$
# - **Mayor $r_{esf}$**: aumenta $A_R$ (cuando hay inmersión) → mayor fuerza de arrastre → mayor amortiguamiento. La estructura converge antes y con menores oscilaciones.
# - **Mayor $\rho_{fl}$**: idem, escala linealmente la fuerza de arrastre ($F_a \propto \rho_{fl}$).
# - En ambos casos, existe un límite a partir del cual el amortiguamiento es tan grande que la estructura prácticamente no alcanza la zona de inmersión (la esfera no llega a $h_{SL}$), y el efecto se satura.
#
# ### Nota sobre la implementación de $A_R$
# La transición continua del área de referencia (de 0 a $\pi r^2$) garantiza que la fuerza de arrastre no tenga discontinuidades abruptas, lo que mejora la estabilidad numérica del integrador BDF.

# %% [markdown]
# ### Parte D: Animación de Resultados
#
# Realizar las animaciones de las respuestas de las estructuras (deformada en el tiempo) del **caso $a.i$**[cite: 48, 49]:
# * **Sin amortiguamiento** (situación original).
# * **Con amortiguamiento** (incorporando el dispositivo del punto c)[cite: 49].

# %% [markdown]
# ### Parte D — Animación sin amortiguamiento (Modelo a.i)
#
# Se anima la estructura deformada usando `FuncAnimation` sobre la solución del **modelo a.i** (deformaciones finitas, sin amortiguador). Se exporta como `Caso4_sin_amortiguamiento.gif`.

# %%
from matplotlib.animation import FuncAnimation
from matplotlib.animation import PillowWriter

tiempos = solucion.t
Y = solucion.y

fig,ax = plt.subplots(figsize=(8,8))

ax.set_aspect('equal')
ax.grid(True)

lineas = []

for _ in range(len(conectividad)):
    linea, = ax.plot([], [], 'b-', lw=2)
    lineas.append(linea)

ax.set_title("Caso 4 - Modelo a.i  - Sin amortiguamiento")

# límites fijos

x_all = coordenadas[:,0]
y_all = coordenadas[:,1]

margen = 5

ax.set_xlim(x_all.min()-margen, x_all.max()+margen)
ax.set_ylim(y_all.min()-margen, y_all.max()+margen)

def actualizar(frame):

    desplaz = Y[:num_grados_libertad, frame]
    pos = desplaz.reshape((-1,2))

    for b,(ni,nj) in enumerate(conectividad):

        x = [pos[ni,0], pos[nj,0]]
        y = [pos[ni,1], pos[nj,1]]

        lineas[b].set_data(x,y)

    ax.set_title(
        f"Modelo a.i  sin amortiguamiento  t={tiempos[frame]:.2f}s"
    )

    return lineas

anim = FuncAnimation(
    fig,
    actualizar,
    frames=range(0, len(tiempos), 5),
    interval=30,
    blit=False
)

anim.save(
    "Caso4_sin_amortiguamiento.gif",
    writer=PillowWriter(fps=20),
    dpi=80
)

plt.close()

# %% [markdown]
# ### Parte D — Animación con amortiguamiento (Modelo a.i)
#
# Misma visualización sobre la solución del **modelo a.i con amortiguador**. Las menores amplitudes de oscilación reflejan la disipación de energía del dispositivo. Exportado como `Caso4_con_amortiguamiento.gif`.

# %%
tiempos = solucion_amortiguada.t
Y = solucion_amortiguada.y

fig, ax = plt.subplots(figsize=(8,8))

ax.set_aspect('equal')
ax.grid(True)

lineas = []

for _ in range(len(conectividad)):
    linea, = ax.plot([], [], 'r-', lw=2)
    lineas.append(linea)

ax.set_title("Caso 4 - Con amortiguamiento")

x_all = coordenadas[:,0]
y_all = coordenadas[:,1]

margen = 5

ax.set_xlim(x_all.min()-margen, x_all.max()+margen)
ax.set_ylim(y_all.min()-margen, y_all.max()+margen)

def actualizar(frame):

    desplaz = Y[:num_grados_libertad, frame]
    pos = desplaz.reshape((-1,2))

    for b,(ni,nj) in enumerate(conectividad):

        x = [pos[ni,0], pos[nj,0]]
        y = [pos[ni,1], pos[nj,1]]

        lineas[b].set_data(x,y)

    ax.set_title(
        f"Con amortiguamiento  t={tiempos[frame]:.2f}s"
    )

    return lineas

anim = FuncAnimation(
    fig,
    actualizar,
    frames=range(0, len(tiempos), 5),
    interval=30,
    blit=False
)

anim.save(
    "Caso4_con_amortiguamiento.gif",
    writer=PillowWriter(fps=20),
    dpi=80
)

plt.close()

# %% [markdown]
# ### Parte D — Animación con deformaciones infinitesimales (Modelo a.ii)
#
# Misma visualización aplicada a la solución del **modelo a.ii** (pequeños desplazamientos / deformaciones infinitesimales), donde las fuerzas internas se linealizan sobre la configuración de referencia. A diferencia del modelo a.i, las oscilaciones se mantienen acotadas en torno a la geometría original. Exportado como Caso4_deformaciones_infinitesimales.gif.

# %%
tiempos = solucion_aii.t
Y = solucion_aii.y

fig, ax = plt.subplots(figsize=(8,8))

ax.set_aspect("equal")
ax.grid(True)

lineas = []

for _ in range(len(conectividad)):
    linea, = ax.plot([], [], "g-", lw=2)
    lineas.append(linea)

ax.set_title("Caso 4 - Modelo a.ii - Deformaciones infinitesimales")

x_all = coordenadas[:,0]
y_all = coordenadas[:,1]

margen = 5

ax.set_xlim(x_all.min()-margen, x_all.max()+margen)
ax.set_ylim(y_all.min()-margen, y_all.max()+margen)

def actualizar(frame):

    desplaz = Y[:num_grados_libertad, frame]
    pos = desplaz.reshape((-1,2))

    for b,(ni,nj) in enumerate(conectividad):

        x = [pos[ni,0], pos[nj,0]]
        y = [pos[ni,1], pos[nj,1]]

        lineas[b].set_data(x,y)

    ax.set_title(
        f"Modelo a.ii  deformaciones infinitesimales  t={tiempos[frame]:.2f}s"
    )

    return lineas

anim = FuncAnimation(
    fig,
    actualizar,
    frames=range(0, len(tiempos), 5),
    interval=30,
    blit=False
)

anim.save(
    "Caso4_deformaciones_infinitesimales.gif",
    writer=PillowWriter(fps=20),
    dpi=80
)

plt.close()

# %% [markdown]
# ### Parte D — Animación comparativa de los tres modelos
#
# Se combinan las tres respuestas en una única animación con tres paneles sincronizados (misma base temporal $t \in [0, 50]$ s, 1000 pasos). De izquierda a derecha:
#
# 1. **Pequeñas deformaciones** (modelo a.ii) — en verde.
# 2. **Deformaciones finitas** sin amortiguamiento (modelo a.i) — en azul.
# 3. **Deformaciones finitas con amortiguamiento** (modelo a.i + dispositivo de la Parte C) — en rojo.
#
# Permite contrastar visualmente la diferencia entre la respuesta linealizada y la no lineal, y el efecto disipativo del amortiguador. Exportado como Caso4_comparacion_3modelos.gif.

# %%
# ── Animación comparativa: pequeñas deformaciones | finitas | amortiguado ──────
# Los tres modelos comparten la misma malla temporal (0-50 s, 1000 pasos)
modelos = [
    (solucion_aii,          "Pequeñas deformaciones (a.ii)",      "g-"),
    (solucion,              "Finitas sin amortiguamiento (a.i)",  "b-"),
    (solucion_amortiguada,  "Finitas con amortiguamiento (a.i)",  "r-"),
]

# Cantidad de frames común (por seguridad, el mínimo de los tres)
n_frames = min(sol.y.shape[1] for sol, _, _ in modelos)
tiempos = modelos[0][0].t

fig, axes = plt.subplots(1, 3, figsize=(18, 6))
fig.suptitle("Caso 4 - Comparación de modelos", fontsize=14)

x_all = coordenadas[:, 0]
y_all = coordenadas[:, 1]
margen = 5

lineas_por_modelo = []
for ax, (sol, titulo, estilo) in zip(axes, modelos):
    ax.set_aspect("equal")
    ax.grid(True)
    ax.set_title(titulo, fontsize=11)
    ax.set_xlim(x_all.min() - margen, x_all.max() + margen)
    ax.set_ylim(y_all.min() - margen, y_all.max() + margen)
    lineas = []
    for _ in range(len(conectividad)):
        linea, = ax.plot([], [], estilo, lw=2)
        lineas.append(linea)
    lineas_por_modelo.append(lineas)

def actualizar(frame):
    artistas = []
    for (sol, _, _), lineas in zip(modelos, lineas_por_modelo):
        desplaz = sol.y[:num_grados_libertad, frame]
        pos = desplaz.reshape((-1, 2))
        for b, (ni, nj) in enumerate(conectividad):
            x = [pos[ni, 0], pos[nj, 0]]
            y = [pos[ni, 1], pos[nj, 1]]
            lineas[b].set_data(x, y)
        artistas.extend(lineas)
    fig.suptitle(f"Caso 4 - Comparación de modelos   t={tiempos[frame]:.2f}s", fontsize=14)
    return artistas

anim = FuncAnimation(
    fig,
    actualizar,
    frames=range(0, n_frames, 5),
    interval=30,
    blit=False
)

anim.save(
    "Caso4_comparacion_3modelos.gif",
    writer=PillowWriter(fps=20),
    dpi=80
)

plt.close()
print("GIF comparativo generado: Caso4_comparacion_3modelos.gif")
# Out:
# GIF comparativo generado: Caso4_comparacion_3modelos.gif
